# %% [markdown]
# # Simulador de memoria

# %% [markdown]
# ##### Primeiramente comecei declarando as variaveis das celulas que foram de a-p e uma variavel temporaria

# %%
a = "00000000"
b = "00000000"
c = "00000000"
d = "00000000"
e = "00000000"
f = "00000000"
g = "00000000"
h = "00000000"
i = "00000000"
j = "00000000"
k = "00000000"
l = "00000000"
m = "00000000"
n = "00000000"
o = "00000000"
p = "00000000"
tmp = ""

# %% [markdown]
# #### Na proxima parte foi criado um loop do tipo while para que a execução do programa apenas pare quando solicitado, além de ter o primeiro bloco de if que compreende a parte de escrita nas celulas da memoria, onde ele verifica um certo se um valor de celular é escrito, se for escrito ele pede para ser escrito o dado de 8 bits e verifica se o dado realmente tem 8 bits, caso não tenha ele diz ser invalido

# %%
while True:
    esc = input("Digite W para escrever, R para ler, L para listar toda a memoria e qualquer tecla para parar: ")
    if esc.lower() == "w":
        end = input("Digite o endereço de 4 bits: ")
        if end == "0000":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                a = tmp

        elif end == "0001":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                b = tmp

        elif end == "0010":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                c = tmp

        elif end == "0011":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                d = tmp

        elif end == "0100":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                e = tmp

        elif end == "0101":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                f = tmp

        elif end == "0110":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                g = tmp

        elif end == "0111":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                h = tmp

        elif end == "1000":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                i = tmp

        elif end == "1001":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                j = tmp

        elif end == "1010":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                k = tmp

        elif end == "1011":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                l = tmp

        elif end == "1100":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                m = tmp

        elif end == "1101":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                n = tmp

        elif end == "1110":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                o = tmp

        elif end == "1111":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                p = tmp

# %% [markdown]
# #### No proximo bloco de if ele permte com que sejam lidos valores individuais das celulas da memoria. Onde o usuario escolhe a opção R e digita o endereço da memoria e ele retorna o valor que está escrito na celula

# %%
 elif esc.lower() == "r":
        end = input("Digite o endereço de 4 bits: ")
        if end == "0000":
            print(a)
        elif end == "0001":
            print(b)
        elif end == "0010":
            print(c)
        elif end == "0011":
            print(d)
        elif end == "0100":
            print(e)
        elif end == "0101":
            print(f)
        elif end == "0110":
            print(g)
        elif end == "0111":
            print(h)
        elif end == "1000":
            print(i)
        elif end == "1001":
            print(j)
        elif end == "1010":
            print(k)
        elif end == "1011":
            print(l)
        elif end == "1100":
            print(m)
        elif end == "1101":
            print(n)
        elif end == "1110":
            print(o)
        elif end == "1111":
            print(p)

# %% [markdown]
# #### O proximo bloco faz a listagem de todas as celulas de memoria, de 0000 a 1111 e também tem o final que permite a saida do programa caso o usuario escreva qualquer coisa que não atenda as funções do simulador

# %%
    elif esc.lower() == "l":
        print("Todos os estados:")
        print(a)
        print(b)
        print(c)
        print(d)
        print(e)
        print(f)
        print(g)
        print(h)
        print(i)
        print(j)
        print(k)
        print(l)
        print(m)
        print(n)
        print(o)
        print(p)

    else:
        exit()

# %% [markdown]
# Por fim se tem a memoria completa que pode ser executada e possui 3 funções,
# ***
# **W para escrita que permite a escrita de dados em celulas individuais**
# ***
# **R para leitura de celulas individuais**
# ***
# **L para listagem do conteudo de todas as celulas**
# ***
# Por fim, caso o usuario digite qualquer coisa que fuja destes o programa se encerra

# %%
a = "00000000"
b = "00000000"
c = "00000000"
d = "00000000"
e = "00000000"
f = "00000000"
g = "00000000"
h = "00000000"
i = "00000000"
j = "00000000"
k = "00000000"
l = "00000000"
m = "00000000"
n = "00000000"
o = "00000000"
p = "00000000"
tmp = ""

while True:
    esc = input("Digite W para escrever, R para ler, L para listar toda a memoria e qualquer tecla para parar: ")
    if esc.lower() == "w":
        end = input("Digite o endereço de 4 bits: ")
        if end == "0000":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                a = tmp

        elif end == "0001":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                b = tmp

        elif end == "0010":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                c = tmp

        elif end == "0011":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                d = tmp

        elif end == "0100":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                e = tmp

        elif end == "0101":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                f = tmp

        elif end == "0110":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                g = tmp

        elif end == "0111":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                h = tmp

        elif end == "1000":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                i = tmp

        elif end == "1001":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                j = tmp

        elif end == "1010":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                k = tmp

        elif end == "1011":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                l = tmp

        elif end == "1100":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                m = tmp

        elif end == "1101":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                n = tmp

        elif end == "1110":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                o = tmp

        elif end == "1111":
            tmp = input("Digite o dado de 8 bits: ")
            if len(tmp) > 8 or len(tmp) < 8:
                print("Valor invalido")
            else:
                p = tmp

    elif esc.lower() == "r":
        end = input("Digite o endereço de 4 bits: ")
        if end == "0000":
            print(a)
        elif end == "0001":
            print(b)
        elif end == "0010":
            print(c)
        elif end == "0011":
            print(d)
        elif end == "0100":
            print(e)
        elif end == "0101":
            print(f)
        elif end == "0110":
            print(g)
        elif end == "0111":
            print(h)
        elif end == "1000":
            print(i)
        elif end == "1001":
            print(j)
        elif end == "1010":
            print(k)
        elif end == "1011":
            print(l)
        elif end == "1100":
            print(m)
        elif end == "1101":
            print(n)
        elif end == "1110":
            print(o)
        elif end == "1111":
            print(p)

    elif esc.lower() == "l":
        print("Todos os estados:")
        print(a)
        print(b)
        print(c)
        print(d)
        print(e)
        print(f)
        print(g)
        print(h)
        print(i)
        print(j)
        print(k)
        print(l)
        print(m)
        print(n)
        print(o)
        print(p)

    else:
        break
